# %% [markdown]
# <a href="https://colab.research.google.com/github/bharahechaura-gif/practice-problem/blob/main/Practice_problem_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 - Check if a number is positive or negative.

# %%
num = int(input("Enter a number: "))

if num >= 0:
  print("the number is positive")
else:
  print("the number is negative")
# Out:
# Enter a number: -5
# the number is negative

# %%
2 -- Check if a number is even or odd.

# %%
num = int(input("enter a number: "))

if num % 2 == 0:
  print("the number is even")
else:
  print("the number is odd")
# Out:
# enter a number: 4
# the number is even

# %%
Q.3. Check if a person is eligible to vote (age ≥ 18).

# %%
age = int(input())

if age >= 18:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# 17
# not eligible to vote

# %%
Q3. Check if a student has passed (marks ≥ 40).

# %%
marks = int(input())

if marks >= 40:
  print("student is pass")
else:
  print("student is fail")
# Out:
# 39
# student is fail

# %%
Q5. Check if a number is greater than 100.

# %%
number = int(input())

if number >= 100:
  print("greater")
else:
  print("smaller")
# Out:
# 99
# smaller

# %%
Q6 Check if a number is divisible by 5.

# %%
num = int(input())

if num % 5 == 0:
  print("The num is divisible by 5")
else:
  print("The num is not divisible by 5")
# Out:
# 113
# The num is not divisible by 5

# %%
Q7. Check if a number is divisible by both 2 and 3.

# %%
num = int(input())

if num % 2 == 0:
  print("the num is divisible by 2")
elif num % 3 == 0:
  print("the num is divisible by 3")

else:
  print("the num is not divisible by both 2, 3")
# Out:
# 5
# the num is not divisible by both 2, 3

# %%
Q8. Check if a number is between 10 and 20 (inclusive).

# %%
num = int(input())

if num >= 10 and num <= 20:
  print("the number is between 10, 20")
else:
  print("the number is not between 10, 20")
# Out:
# 15
# the number is between 10, 20

# %%
num = int(input())

if num >= 10 and num <= 20:
  print("the number is between 10, 20")
else:
  print("the number is not between 10, 20")
# Out:
# 21
# the number is not between 10, 20

# %%
Q9. Check if a person is a child (age < 13) or an adult.

# %%
age = int(input())

if age < 13:
  print("person is child")
else:
  print("person is adult")
# Out:
# 14
# person is adult

# %%
age = int(input())

if age < 13:
  print("person is child")
else:
  print("person is adult")
# Out:
# 11
# person is child
