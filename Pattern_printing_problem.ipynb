# %% [markdown]
# <a href="https://colab.research.google.com/github/bharahechaura-gif/practice-problem/blob/main/Pattern_printing_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pattern printing problems

# %%
*
*
*
*
*

# %%
for i in range(5):
  print("*")
# Out:
# *
# *
# *
# *
# *

# %%
*****
*****
*****
*****
*****

# %%
for i in range(5):
  print("*****")
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
*
**
***
****
*****

# %%
n = 5
for i in range(1, n + 1):
  for j in range(i):
    print("*", end ="")

  print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
*****
****
***
**
*

# %%
n = 5
for i in range(n, 0, -1):
  for j in range(i):
    print("*", end = "")

  print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
1
12
123
1234
12345

# %%
n = 5
for i in range(1, n + 1):
  for j in range(1, i + 1):
    print(j, end="")

  print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
12345
1234
123
12
1

# %%
n = 5

for i in range(n, 0, -1):
  for j in range(1, i + 1):
    print(j, end="")

  print()
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
    *
   ***
  *****
 *******
*********

# %%
n = 5

for i in range(1, n + 1):
   for j in range(n - i):
        print(" ", end="")
   for j in range(2 * i - 1):
        print("*", end="")

   print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
*********
 *******
  *****
   ***
    *

# %%
n = 5

for i in range(n, 0, -1):
   for j in range(n - i):
        print(" ", end="")
   for j in range(2 * i - 1):
        print("*", end="")

   print()
# Out:
# *********
#  *******
#   *****
#    ***
#     *

# %%
* * *
* * *
* * *
* * *

# %%
n = 4

for i in range(4):
  for j in range(3):
    print("*", end = " ")

  print()
# Out:
# * * *
# * * *
# * * *
# * * *

# %%
*
**
***
****

# %%
for i in range(1, 5):
  for j in range(i):
    print("*", end ="")
  print()
# Out:
# *
# **
# ***
# ****

# %%
****
***
**
*

# %%
for i in range(4, 0, -1):
  for j in range(i):
    print("*", end ="")
  print()
# Out:
# ****
# ***
# **
# *

# %%
******
*****
****
***
**
*

# %%
for i in range(6, 0, -1):
  for j in range(i):
    print("*", end ="")

  print()
# Out:
# ******
# *****
# ****
# ***
# **
# *

# %%
*
**
***
****
*****
******

# %%
n = 6

for i in range(1, 7):
  for j in range(i):
    print("*", end ="")

  print()
# Out:
# *
# **
# ***
# ****
# *****
# ******

# %%
    *
   ***
  *****
 *******
*********

# %%
n = 5

for i in range(1, n + 1):
    for j in range(n - i):
        print(" ", end="")

    for j in range(2 * i - 1):
        print("*", end="")

    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
1
2
3
4
5

# %%
for i in range(1, 6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
1 1 1 1 1

# %%
for i in range(5):
  print(1, end=" ")
# Out:
# 1 1 1 1 1

# %%
11 11 11 11 11 11 11

# %%
for i in range(7):
  print(11, end=" ")
# Out:
# 11 11 11 11 11 11 11

# %%
11 11 11 11 11 11
11 11 11 11 11 11

# %%
for i in range(2):
  for j in range(6):
    print(11, end=" ")

  print()
# Out:
# 11 11 11 11 11 11
# 11 11 11 11 11 11

# %%
111
111
111

# %%
n = 3
for i in range(3):
  for j in range(3):
    print(1, end="")
  print()
# Out:
# 111
# 111
# 111

# %%
1
12
123
1234

# %%
for i in range(1, 5):
    for j in range(1, i + 1):
        print(j, end="")
    print()
# Out:
# 1
# 12
# 123
# 1234

# %%
1
22
333
4444

# %%
for i in range(1, 5):
  for j in range(i):
    print(i, end="")

  print()
# Out:
# 1
# 22
# 333
# 4444

# %%
*
**
***
****
*****

# %%
n = 5

for i in range(1, 6):
  for j in range(i):
   print("*", end ="")

  print()
# Out:
# *
# **
# ***
# ****
# *****
